# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import os
import gc
import random
from sklearn.model_selection import GroupKFold, KFold, StratifiedKFold
import seaborn as sns
import pickle
import json
import re
import time
import sys
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

import warnings
warnings.filterwarnings('ignore')

# %%
tfn1 = 'train_data_25n_'
tfn2 = 'valid_data_25n_'

ffn1 = 'train_fuzz_data_25n_'
ffn2 = 'valid_fuzz_data_25n_'

nsets = 3
model_file_name = 'fuzz_from_872'

# %%
tdata = pd.read_csv('../src/data/raw/train.csv')

tdata['name'] = tdata['name'].isna().astype(int)
tdata['categories'] = tdata['categories'].isna().astype(int)
tdata['address'] = tdata['address'].isna().astype(int)
tdata['state'] = tdata['state'].isna().astype(int)
tdata['url'] = tdata['url'].isna().astype(int)
tdata['country'] = tdata['country'].isna().astype(int)

tdata = tdata[['id','name', 'categories', 'address', 'state', 
               'url', 'country']].drop_duplicates().reset_index(drop=True)

# %%
def prepare_data(df_set, fuzz_set):
    
    train_df = []
    
    for i in range(1, nsets+1):
    
        t1 = pd.read_csv('../src/data/processed/'+df_set+str(i)+'.csv')
        print(t1.shape)
        t1['kdist_diff'] = (t1['kdist'] - t1['kdist_country'])/t1['kdist_country']
        t1['kneighbors_mean'] = t1[['kneighbors', 'kneighbors_country']].mean(axis = 1)
        
        t1['sim_mean'] = (t1['kneighbors_mean']+t1[[col for col in t1.columns if 'sim' in col]].mean(axis=1))/2.
        t1['jaro_mean'] = (t1['kneighbors_mean']+t1[[col for col in t1.columns if 'jaro' in col]].mean(axis=1))/2.
        t1['lcs_mean'] = (t1['kneighbors_mean']+t1[[col for col in t1.columns if '_lcs' in col]].mean(axis=1))/2.   
        
        t1 = t1.drop('kneighbors_mean', axis=1)
        
        t1['sim_sum'] = t1[[col for col in t1.columns if 'sim' in col]].sum(axis=1)
        t1['gesh_sum'] = t1[[col for col in t1.columns if 'gesh' in col]].sum(axis=1)
        t1['leven_sum'] = t1[[col for col in t1.columns if '_leven' in col]].sum(axis=1)
        t1['jaro_sum'] = t1[[col for col in t1.columns if 'jaro' in col]].sum(axis=1)
        t1['lcs_sum'] = t1[[col for col in t1.columns if '_lcs' in col]].sum(axis=1)
        t1['nlcsk_sum'] = t1[[col for col in t1.columns if '_nlcsk' in col]].sum(axis=1)
        t1['nleven_sum'] = t1[[col for col in t1.columns if '_nleven' in col]].sum(axis=1)
        t1['nlcs_sum'] = t1[[col for col in t1.columns if '_nlcs' in col]].sum(axis=1)

        t1['sim_std'] = t1[[col for col in t1.columns if 'sim' in col]].std(axis=1)
        t1['gesh_std'] = t1[[col for col in t1.columns if 'gesh' in col]].std(axis=1)
        t1['leven_std'] = t1[[col for col in t1.columns if '_leven' in col]].std(axis=1)
        t1['jaro_std'] = t1[[col for col in t1.columns if 'jaro' in col]].std(axis=1)
        t1['lcs_std'] = t1[[col for col in t1.columns if '_lcs' in col]].std(axis=1)
        t1['nlcsk_std'] = t1[[col for col in t1.columns if '_nlcsk' in col]].std(axis=1)
        t1['nleven_std'] = t1[[col for col in t1.columns if '_nleven' in col]].std(axis=1)
        t1['nlcs_std'] = t1[[col for col in t1.columns if '_nlcs' in col]].std(axis=1)

        t1 = t1.merge(tdata, on='id', how='left')
        t1 = t1.merge(tdata, left_on='match_id', right_on='id', how='left', suffixes=['_1','_2'])
        t1 = t1.drop('id_2', axis=1).rename(columns={'id_1':'id'})
        
        t1['info_power_1'] = t1[[col for col in t1.columns if '_1' in col]].lt(1).sum(axis=1)
        t1['info_power_2'] = t1[[col for col in t1.columns if '_2' in col]].lt(1).sum(axis=1)
        t1['info_diff'] = t1['info_power_1'] - t1['info_power_2']
        
        t1['kdist_diff_x_info_diff'] = t1['kdist_diff']*t1['info_diff']
        
        t1 = t1.drop([col for col in t1.columns if '_1' in col], axis=1)
        t1 = t1.drop([col for col in t1.columns if '_2' in col], axis=1)
        gc.collect()
        
        f1 = pd.read_csv('../src/data/processed/'+fuzz_set+str(i)+'.csv')
        drop_cols = ['url_w_ratio', 'url_partial_ratio','url_tokenset_ratio', 'url_tokensort_ratio', 'url_fuzz_power']
        f1 = f1.drop(drop_cols, axis=1)
        f1 = f1.drop(['id','match_id','kdist','kneighbors','kdist_country','kneighbors_country','label'], axis=1)
        
        t1 = pd.concat([t1, f1], axis=1)
        
        print(t1.shape)
        
        del f1
        gc.collect()
        
        train_df.append(t1)
        
        del t1
        gc.collect()
    
    return train_df

# %%
# %%time
train_df = prepare_data(tfn1, ffn1)
# Out:
# (5837212, 77)
# (5837212, 114)
# (5848974, 77)
# (5848974, 114)
# (5831684, 77)
# (5831684, 114)
# CPU times: user 6min 56s, sys: 2min 35s, total: 9min 32s
# Wall time: 9min 40s

# %%
# %%time
train_df = pd.concat(train_df).reset_index(drop=True)
# Out:
# CPU times: user 20.7 s, sys: 14.5 s, total: 35.2 s
# Wall time: 35.2 s

# %%
train_df.shape
# Out:
# (17517870, 114)

# %%
# %%time
valid_df = prepare_data(tfn2, ffn2)
# Out:
# (5838073, 77)
# (5838073, 114)
# (5836792, 77)
# (5836792, 114)
# (5837910, 77)
# (5837910, 114)
# CPU times: user 7min 11s, sys: 2min 42s, total: 9min 53s
# Wall time: 10min 5s

# %%
# %%time
valid_df = pd.concat(valid_df).reset_index(drop=True)
# Out:
# CPU times: user 26.2 s, sys: 20.9 s, total: 47.2 s
# Wall time: 47.2 s

# %%
valid_df.shape
# Out:
# (17512775, 114)

# %%
train_df.label.value_counts()
# Out:
# 0    16489259
# 1     1028611
# Name: label, dtype: int64

# %%
valid_df.label.value_counts()
# Out:
# 0    16490264
# 1     1022511
# Name: label, dtype: int64

# %%
train_df = pd.concat([train_df, valid_df], axis=0).reset_index(drop=True)

del valid_df
gc.collect()
# Out:
# 0

# %%
TRAIN_FEATURES = ['kdist', 'kneighbors', 'kdist_country', 'kneighbors_country', 'kdist_diff', 
#                 'kneighbors_mean', 
                'name_sim', 'name_gesh','name_leven', 'name_jaro', 'name_lcs', 'name_len_diff', 'name_nleven', 
                'name_nlcsk', 'name_nlcs', 'address_sim', 'address_gesh', 'address_leven', 'address_jaro', 
                'address_lcs', 'address_len_diff', 'address_nleven', 'address_nlcsk', 'address_nlcs', 'city_gesh', 
                'city_leven', 'city_jaro', 'city_lcs', 'city_len_diff', 
                'city_nleven', 'city_nlcsk', 'city_nlcs', 'state_sim', 'state_gesh', 'state_leven', 'state_jaro', 
                'state_lcs', 'state_len_diff', 'state_nleven', 'state_nlcsk', 'state_nlcs', 'zip_gesh', 'zip_leven', 
                'zip_jaro', 'zip_lcs', 
#                 'url_sim', 'url_gesh', 'url_leven', 'url_jaro', 'url_lcs', 'url_len_diff', 'url_nleven', 'url_nlcsk', 
#                 'url_nlcs', 
                'phone_gesh', 'phone_leven', 'phone_jaro', 'phone_lcs', 'categories_sim', 'categories_gesh', 
                'categories_leven', 'categories_jaro', 'categories_lcs', 'categories_len_diff', 'categories_nleven', 
                'categories_nlcsk', 'categories_nlcs', 
#                 'country_sim', 'country_gesh', 'country_leven', 'country_nleven', 
                'sim_sum', 'gesh_sum', 'leven_sum', 'jaro_sum','lcs_sum', 'sim_std', 'gesh_std', 'leven_std',
                'jaro_std', 'lcs_std', 'info_diff', 'nleven_sum', 'nlcsk_sum', 'nlcs_sum', 'nleven_std', 
                'nlcsk_std', 'nlcs_std', 'sim_mean','jaro_mean','lcs_mean','kdist_diff_x_info_diff',
                'name_w_ratio', 'name_partial_ratio', 'name_tokenset_ratio', 'name_tokensort_ratio', 
                'name_fuzz_power', 'categories_w_ratio', 'categories_partial_ratio', 'categories_tokenset_ratio', 
                'categories_tokensort_ratio', 'categories_fuzz_power', 'address_w_ratio', 'address_partial_ratio', 
                'address_tokenset_ratio', 'address_tokensort_ratio', 'address_fuzz_power', 
#                 'url_w_ratio', 'url_partial_ratio', 'url_tokenset_ratio', 'url_tokensort_ratio', 'url_fuzz_power'
                ]

len(TRAIN_FEATURES)
# Out:
# 93

# %%
NFOLDS = 7
kf = StratifiedKFold(n_splits = NFOLDS, shuffle=True, random_state=42)
for i, (trn_idx, val_idx) in tqdm(enumerate(kf.split(train_df, train_df["label"], train_df["label"]))):
    train_df.loc[val_idx, "fold"] = i
# Out:
# 0it [00:00, ?it/s]

# %%
train_df.label.value_counts()/len(train_df)
# Out:
# 0    0.941448
# 1    0.058552
# Name: label, dtype: float64

# %%
import lightgbm as lgbm

def fit_lgbm(X, y, params=None, es_rounds=20, seed=42, N_SPLITS=5, 
             n_class=None, model_dir=None, folds=None):
    
    models = []
    oof = np.zeros((len(y), n_class), dtype=np.float64)
    
    for i in tqdm(range(NFOLDS)):
        print(f"== fold {i} ==")
        trn_idx = folds!=i
        val_idx = folds==i
        X_train, y_train = X[trn_idx], y.iloc[trn_idx]
        X_valid, y_valid = X.iloc[val_idx], y.iloc[val_idx]

        if model_dir is None:
            model = lgbm.LGBMClassifier(**params)
            model.fit(
                X_train, y_train, 
                eval_set=[(X_valid, y_valid)],  
                early_stopping_rounds=es_rounds, 
                verbose=50)
        else:
            with open(f'../src/models/BinaryModels/{model_file_name}{i}.pkl', 'rb') as f:
                model = pickle.load(f)
            
        pred = model.predict_proba(X_valid)
        oof[val_idx] = pred
        models.append(model)
        
        file = f'../src/models/BinaryModels/{model_file_name}{i}.pkl'
        pickle.dump(model, open(file, 'wb'))
        print()

    cv = (oof.argmax(axis=-1) == y).mean()
    print(f"CV-accuracy: {cv}")

    return oof, models

def inference_lgbm(models, feat_df):
    pred = np.array([model.predict_proba(feat_df) for model in models])
    pred = np.mean(pred, axis=0)
    return pred

# %%
params = {
    'boosting_type': 'gbdt', 
    'objective': 'binary', 
    'tree_learner': 'feature',
    'metric': ['binary_logloss', 'AUC'],
    'learning_rate': 0.3,
    'reg_alpha': 0.2926,
    'reg_lambda': 0.582,
    'random_state': 2018,
    'max_depth': 8,
    'num_leaves': 127, 
    'n_estimators': 3000,
    "colsample_bytree": 0.285,
    "first_metric_only": True,
    "max_bin": 512
}

oof, models = fit_lgbm(train_df[TRAIN_FEATURES], train_df["label"].astype(int), 
                       params=params, n_class=int(train_df["label"].max() + 1), 
                       N_SPLITS=NFOLDS, folds=train_df["fold"].values)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# == fold 0 ==
# [50]	valid_0's binary_logloss: 0.0347916	valid_0's auc: 0.994114
# [100]	valid_0's binary_logloss: 0.033111	valid_0's auc: 0.994731
# [150]	valid_0's binary_logloss: 0.0322348	valid_0's auc: 0.995032
# [200]	valid_0's binary_logloss: 0.0315439	valid_0's auc: 0.995266
# [250]	valid_0's binary_logloss: 0.0311056	valid_0's auc: 0.995409
# [300]	valid_0's binary_logloss: 0.0306481	valid_0's auc: 0.995565
# [350]	valid_0's binary_logloss: 0.030254	valid_0's auc: 0.995687
# [400]	valid_0's binary_logloss: 0.0299244	valid_0's auc: 0.99578
# [450]	valid_0's binary_logloss: 0.0296111	valid_0's auc: 0.99588
# [500]	valid_0's binary_logloss: 0.0293471	valid_0's auc: 0.995961
# [550]	valid_0's binary_logloss: 0.0291195	valid_0's auc: 0.996032
# [600]	valid_0's binary_logloss: 0.0288693	valid_0's auc: 0.996107
# [650]	valid_0's binary_logloss: 0.0286391	valid_0's auc: 0.996177
# [700]	valid_0's binary_logloss: 0.0284141	valid_0's auc: 0.996245
# [750]	valid_0's binary_logloss: 0.0282139	valid_0's auc: 0.996301
# [800]	valid_0's binary_logloss: 0.0279684	valid_0's auc: 0.99638
# [850]	valid_0's binary_logloss: 0.0277476	valid_0's auc: 0.996439
# [900]	valid_0's binary_logloss: 0.0275488	valid_0's auc: 0.996494
# [950]	valid_0's binary_logloss: 0.0273213	valid_0's auc: 0.996566
# [1000]	valid_0's binary_logloss: 0.0271448	valid_0's auc: 0.996606
# [1050]	valid_0's binary_logloss: 0.0269669	valid_0's auc: 0.99665
# [1100]	valid_0's binary_logloss: 0.0267801	valid_0's auc: 0.9967
# [1150]	valid_0's binary_logloss: 0.0265646	valid_0's auc: 0.996756
# [1200]	valid_0's binary_logloss: 0.0263967	valid_0's auc: 0.996804
# [1250]	valid_0's binary_logloss: 0.0262338	valid_0's auc: 0.996843
# [1300]	valid_0's binary_logloss: 0.0260808	valid_0's auc: 0.996883
# [1350]	valid_0's binary_logloss: 0.0259115	valid_0's auc: 0.996925
# [1400]	valid_0's binary_logloss: 0.0257613	valid_0's auc: 0.996966
# [1450]	valid_0's binary_logloss: 0.0256219	valid_0's auc: 0.996996
# [1500]	valid_0's binary_logloss: 0.0254785	valid_0's auc: 0.997033
# [1550]	valid_0's binary_logloss: 0.0253248	valid_0's auc: 0.997069
# [1600]	valid_0's binary_logloss: 0.0251822	valid_0's auc: 0.997101
# [1650]	valid_0's binary_logloss: 0.0250497	valid_0's auc: 0.997131
# [1700]	valid_0's binary_logloss: 0.0249089	valid_0's auc: 0.997168
# [1750]	valid_0's binary_logloss: 0.0247821	valid_0's auc: 0.997193
# [1800]	valid_0's binary_logloss: 0.0246532	valid_0's auc: 0.997216
# [1850]	valid_0's binary_logloss: 0.0245165	valid_0's auc: 0.997246
# [1900]	valid_0's binary_logloss: 0.0243627	valid_0's auc: 0.99728
# [1950]	valid_0's binary_logloss: 0.0242398	valid_0's auc: 0.997307
# [2000]	valid_0's binary_logloss: 0.0241235	valid_0's auc: 0.997331
# [2050]	valid_0's binary_logloss: 0.0239828	valid_0's auc: 0.997363
# [2100]	valid_0's binary_logloss: 0.0238679	valid_0's auc: 0.997389
# [2150]	valid_0's binary_logloss: 0.0237395	valid_0's auc: 0.997419
# [2200]	valid_0's binary_logloss: 0.0236231	valid_0's auc: 0.997439
# [2250]	valid_0's binary_logloss: 0.0235144	valid_0's auc: 0.997463
# [2300]	valid_0's binary_logloss: 0.0233965	valid_0's auc: 0.997486
# [2350]	valid_0's binary_logloss: 0.0232934	valid_0's auc: 0.997504
# [2400]	valid_0's binary_logloss: 0.0232093	valid_0's auc: 0.997518
# [2450]	valid_0's binary_logloss: 0.0231041	valid_0's auc: 0.997539
# [2500]	valid_0's binary_logloss: 0.023004	valid_0's auc: 0.997559
# [2550]	valid_0's binary_logloss: 0.0228891	valid_0's auc: 0.997584
# [2600]	valid_0's binary_logloss: 0.0227852	valid_0's auc: 0.997606
# [2650]	valid_0's binary_logloss: 0.022677	valid_0's auc: 0.997628
# [2700]	valid_0's binary_logloss: 0.0225984	valid_0's auc: 0.997643
# [2750]	valid_0's binary_logloss: 0.0224865	valid_0's auc: 0.997666
# [2800]	valid_0's binary_logloss: 0.0223892	valid_0's auc: 0.997684
# [2850]	valid_0's binary_logloss: 0.0223052	valid_0's auc: 0.997701
# [2900]	valid_0's binary_logloss: 0.0222092	valid_0's auc: 0.997716
# [2950]	valid_0's binary_logloss: 0.0221238	valid_0's auc: 0.997733
# [3000]	valid_0's binary_logloss: 0.0220391	valid_0's auc: 0.997747
#
# == fold 1 ==
# [50]	valid_0's binary_logloss: 0.0346302	valid_0's auc: 0.994193
# [100]	valid_0's binary_logloss: 0.0329628	valid_0's auc: 0.994776
# [150]	valid_0's binary_logloss: 0.0320303	valid_0's auc: 0.995099
# [200]	valid_0's binary_logloss: 0.031487	valid_0's auc: 0.995295
# [250]	valid_0's binary_logloss: 0.030937	valid_0's auc: 0.995488
# [300]	valid_0's binary_logloss: 0.0305241	valid_0's auc: 0.995627
# [350]	valid_0's binary_logloss: 0.0301548	valid_0's auc: 0.995747
# [400]	valid_0's binary_logloss: 0.029862	valid_0's auc: 0.995839
# [450]	valid_0's binary_logloss: 0.0295478	valid_0's auc: 0.995927
# [500]	valid_0's binary_logloss: 0.0292339	valid_0's auc: 0.996027
# [550]	valid_0's binary_logloss: 0.0289722	valid_0's auc: 0.996112
# [600]	valid_0's binary_logloss: 0.0287049	valid_0's auc: 0.996186
# [650]	valid_0's binary_logloss: 0.0284623	valid_0's auc: 0.99626
# [700]	valid_0's binary_logloss: 0.0282558	valid_0's auc: 0.996322
# [750]	valid_0's binary_logloss: 0.0280413	valid_0's auc: 0.996382
# [800]	valid_0's binary_logloss: 0.0277977	valid_0's auc: 0.996453
# [850]	valid_0's binary_logloss: 0.0275787	valid_0's auc: 0.996514
# [900]	valid_0's binary_logloss: 0.0273891	valid_0's auc: 0.996566
# [950]	valid_0's binary_logloss: 0.0272161	valid_0's auc: 0.99661
# [1000]	valid_0's binary_logloss: 0.0270171	valid_0's auc: 0.996652
# [1050]	valid_0's binary_logloss: 0.0268163	valid_0's auc: 0.996709
# [1100]	valid_0's binary_logloss: 0.0266265	valid_0's auc: 0.996757
# [1150]	valid_0's binary_logloss: 0.0264764	valid_0's auc: 0.996798
# [1200]	valid_0's binary_logloss: 0.0263258	valid_0's auc: 0.996832
# [1250]	valid_0's binary_logloss: 0.0261841	valid_0's auc: 0.996872
# [1300]	valid_0's binary_logloss: 0.0260164	valid_0's auc: 0.99691
# [1350]	valid_0's binary_logloss: 0.0258622	valid_0's auc: 0.99695
# [1400]	valid_0's binary_logloss: 0.0257111	valid_0's auc: 0.996984
# [1450]	valid_0's binary_logloss: 0.0255566	valid_0's auc: 0.997021
# [1500]	valid_0's binary_logloss: 0.0253981	valid_0's auc: 0.997057
# [1550]	valid_0's binary_logloss: 0.0252721	valid_0's auc: 0.997085
# [1600]	valid_0's binary_logloss: 0.025148	valid_0's auc: 0.997114
# [1650]	valid_0's binary_logloss: 0.0250177	valid_0's auc: 0.997143
# [1700]	valid_0's binary_logloss: 0.0249019	valid_0's auc: 0.997163
# [1750]	valid_0's binary_logloss: 0.0247675	valid_0's auc: 0.997194
# [1800]	valid_0's binary_logloss: 0.0246305	valid_0's auc: 0.99723
# [1850]	valid_0's binary_logloss: 0.0245018	valid_0's auc: 0.997258
# [1900]	valid_0's binary_logloss: 0.0243955	valid_0's auc: 0.997281
# [1950]	valid_0's binary_logloss: 0.0242736	valid_0's auc: 0.997306
# [2000]	valid_0's binary_logloss: 0.0241502	valid_0's auc: 0.997335
# [2050]	valid_0's binary_logloss: 0.0240136	valid_0's auc: 0.997368
# [2100]	valid_0's binary_logloss: 0.0239035	valid_0's auc: 0.997391
# [2150]	valid_0's binary_logloss: 0.0237736	valid_0's auc: 0.997417
# [2200]	valid_0's binary_logloss: 0.0236577	valid_0's auc: 0.997441
# [2250]	valid_0's binary_logloss: 0.0235514	valid_0's auc: 0.997464
# [2300]	valid_0's binary_logloss: 0.0234404	valid_0's auc: 0.997484
# [2350]	valid_0's binary_logloss: 0.0233345	valid_0's auc: 0.997504
# [2400]	valid_0's binary_logloss: 0.0232132	valid_0's auc: 0.997529
# [2450]	valid_0's binary_logloss: 0.0230907	valid_0's auc: 0.997555
# [2500]	valid_0's binary_logloss: 0.0229959	valid_0's auc: 0.997576
# [2550]	valid_0's binary_logloss: 0.0228909	valid_0's auc: 0.997595
# [2600]	valid_0's binary_logloss: 0.0227829	valid_0's auc: 0.997617
# [2650]	valid_0's binary_logloss: 0.0226765	valid_0's auc: 0.997635
# [2700]	valid_0's binary_logloss: 0.0225869	valid_0's auc: 0.997649
# [2750]	valid_0's binary_logloss: 0.0224903	valid_0's auc: 0.997669
# [2800]	valid_0's binary_logloss: 0.0223662	valid_0's auc: 0.997691
# [2850]	valid_0's binary_logloss: 0.0222878	valid_0's auc: 0.997703
# [2900]	valid_0's binary_logloss: 0.0221881	valid_0's auc: 0.99772
# [2950]	valid_0's binary_logloss: 0.0220975	valid_0's auc: 0.997734
# [3000]	valid_0's binary_logloss: 0.0220191	valid_0's auc: 0.997747
#
# == fold 2 ==
# [50]	valid_0's binary_logloss: 0.0344383	valid_0's auc: 0.994333
# [100]	valid_0's binary_logloss: 0.0326414	valid_0's auc: 0.994975
# [150]	valid_0's binary_logloss: 0.0318495	valid_0's auc: 0.995248
# [200]	valid_0's binary_logloss: 0.0312503	valid_0's auc: 0.995446
# [250]	valid_0's binary_logloss: 0.0307296	valid_0's auc: 0.995619
# [300]	valid_0's binary_logloss: 0.0303148	valid_0's auc: 0.995743
# [350]	valid_0's binary_logloss: 0.029957	valid_0's auc: 0.995848
# [400]	valid_0's binary_logloss: 0.0295837	valid_0's auc: 0.995982
# [450]	valid_0's binary_logloss: 0.0292771	valid_0's auc: 0.99606
# [500]	valid_0's binary_logloss: 0.0289614	valid_0's auc: 0.996153
# [550]	valid_0's binary_logloss: 0.0286699	valid_0's auc: 0.996244
# [600]	valid_0's binary_logloss: 0.0284163	valid_0's auc: 0.996319
# [650]	valid_0's binary_logloss: 0.0281592	valid_0's auc: 0.996392
# [700]	valid_0's binary_logloss: 0.0279064	valid_0's auc: 0.996467
# [750]	valid_0's binary_logloss: 0.0276762	valid_0's auc: 0.996524
# [800]	valid_0's binary_logloss: 0.027457	valid_0's auc: 0.996592
# [850]	valid_0's binary_logloss: 0.0272418	valid_0's auc: 0.996649
# [900]	valid_0's binary_logloss: 0.0270693	valid_0's auc: 0.996694
# [950]	valid_0's binary_logloss: 0.0268764	valid_0's auc: 0.996739
# [1000]	valid_0's binary_logloss: 0.0266952	valid_0's auc: 0.996786
# [1050]	valid_0's binary_logloss: 0.0265197	valid_0's auc: 0.996831
# [1100]	valid_0's binary_logloss: 0.0263389	valid_0's auc: 0.99687
# [1150]	valid_0's binary_logloss: 0.0261648	valid_0's auc: 0.996913
# [1200]	valid_0's binary_logloss: 0.025987	valid_0's auc: 0.996957
# [1250]	valid_0's binary_logloss: 0.0258218	valid_0's auc: 0.997
# [1300]	valid_0's binary_logloss: 0.0256558	valid_0's auc: 0.997038
# [1350]	valid_0's binary_logloss: 0.0255076	valid_0's auc: 0.99707
# [1400]	valid_0's binary_logloss: 0.0253599	valid_0's auc: 0.997106
# [1450]	valid_0's binary_logloss: 0.0252258	valid_0's auc: 0.997135
# [1500]	valid_0's binary_logloss: 0.0250972	valid_0's auc: 0.997164
# [1550]	valid_0's binary_logloss: 0.0249659	valid_0's auc: 0.997193
# [1600]	valid_0's binary_logloss: 0.0248184	valid_0's auc: 0.997224
# [1650]	valid_0's binary_logloss: 0.0246947	valid_0's auc: 0.997251
# [1700]	valid_0's binary_logloss: 0.0245334	valid_0's auc: 0.997286
# [1750]	valid_0's binary_logloss: 0.0244201	valid_0's auc: 0.997312
# [1800]	valid_0's binary_logloss: 0.0242985	valid_0's auc: 0.997345
# [1850]	valid_0's binary_logloss: 0.0241487	valid_0's auc: 0.997373
# [1900]	valid_0's binary_logloss: 0.0240083	valid_0's auc: 0.997405
# [1950]	valid_0's binary_logloss: 0.0238689	valid_0's auc: 0.997432
# [2000]	valid_0's binary_logloss: 0.0237695	valid_0's auc: 0.99745
# [2050]	valid_0's binary_logloss: 0.0236524	valid_0's auc: 0.997476
# [2100]	valid_0's binary_logloss: 0.0235345	valid_0's auc: 0.997501
# [2150]	valid_0's binary_logloss: 0.0234088	valid_0's auc: 0.997525
# [2200]	valid_0's binary_logloss: 0.0232994	valid_0's auc: 0.997546
# [2250]	valid_0's binary_logloss: 0.0231872	valid_0's auc: 0.997566
# [2300]	valid_0's binary_logloss: 0.0230685	valid_0's auc: 0.997591
# [2350]	valid_0's binary_logloss: 0.0229371	valid_0's auc: 0.997615
# [2400]	valid_0's binary_logloss: 0.0228209	valid_0's auc: 0.997636
# [2450]	valid_0's binary_logloss: 0.0227306	valid_0's auc: 0.997649
# [2500]	valid_0's binary_logloss: 0.0226206	valid_0's auc: 0.997671
# [2550]	valid_0's binary_logloss: 0.0225197	valid_0's auc: 0.997689
# [2600]	valid_0's binary_logloss: 0.0224247	valid_0's auc: 0.997708
# [2650]	valid_0's binary_logloss: 0.0223314	valid_0's auc: 0.997727
# [2700]	valid_0's binary_logloss: 0.0222331	valid_0's auc: 0.997745
# [2750]	valid_0's binary_logloss: 0.0221449	valid_0's auc: 0.997762
# [2800]	valid_0's binary_logloss: 0.0220398	valid_0's auc: 0.997781
# [2850]	valid_0's binary_logloss: 0.0219365	valid_0's auc: 0.997803
# [2900]	valid_0's binary_logloss: 0.0218353	valid_0's auc: 0.99782
# [2950]	valid_0's binary_logloss: 0.0217382	valid_0's auc: 0.997838
# [3000]	valid_0's binary_logloss: 0.0216375	valid_0's auc: 0.997856
#
# == fold 3 ==
# [50]	valid_0's binary_logloss: 0.0346714	valid_0's auc: 0.994191
# [100]	valid_0's binary_logloss: 0.0330781	valid_0's auc: 0.994751
# [150]	valid_0's binary_logloss: 0.0321062	valid_0's auc: 0.995088
# [200]	valid_0's binary_logloss: 0.0315057	valid_0's auc: 0.995298
# [250]	valid_0's binary_logloss: 0.031001	valid_0's auc: 0.995456
# [300]	valid_0's binary_logloss: 0.0305171	valid_0's auc: 0.995612
# [350]	valid_0's binary_logloss: 0.0301585	valid_0's auc: 0.995732
# [400]	valid_0's binary_logloss: 0.0298083	valid_0's auc: 0.995843
# [450]	valid_0's binary_logloss: 0.0295004	valid_0's auc: 0.995937
# [500]	valid_0's binary_logloss: 0.0291909	valid_0's auc: 0.996031
# [550]	valid_0's binary_logloss: 0.0289486	valid_0's auc: 0.996104
# [600]	valid_0's binary_logloss: 0.0287183	valid_0's auc: 0.996166
# [650]	valid_0's binary_logloss: 0.02845	valid_0's auc: 0.99625
# [700]	valid_0's binary_logloss: 0.0282033	valid_0's auc: 0.996325
# [750]	valid_0's binary_logloss: 0.0280313	valid_0's auc: 0.996369
# [800]	valid_0's binary_logloss: 0.02784	valid_0's auc: 0.996419
# [850]	valid_0's binary_logloss: 0.0276115	valid_0's auc: 0.996481
# [900]	valid_0's binary_logloss: 0.0274248	valid_0's auc: 0.996536
# [950]	valid_0's binary_logloss: 0.0272281	valid_0's auc: 0.996581
# [1000]	valid_0's binary_logloss: 0.0270593	valid_0's auc: 0.996621
# [1050]	valid_0's binary_logloss: 0.0268982	valid_0's auc: 0.996663
# [1100]	valid_0's binary_logloss: 0.0267255	valid_0's auc: 0.996704
# [1150]	valid_0's binary_logloss: 0.026546	valid_0's auc: 0.99675
# [1200]	valid_0's binary_logloss: 0.0263954	valid_0's auc: 0.99679
# [1250]	valid_0's binary_logloss: 0.0262587	valid_0's auc: 0.996823
# [1300]	valid_0's binary_logloss: 0.0261119	valid_0's auc: 0.996855
# [1350]	valid_0's binary_logloss: 0.0259513	valid_0's auc: 0.996894
# [1400]	valid_0's binary_logloss: 0.0257913	valid_0's auc: 0.99693
# [1450]	valid_0's binary_logloss: 0.0256242	valid_0's auc: 0.996975
# [1500]	valid_0's binary_logloss: 0.0254839	valid_0's auc: 0.997009
# [1550]	valid_0's binary_logloss: 0.0253511	valid_0's auc: 0.997039
# [1600]	valid_0's binary_logloss: 0.0252243	valid_0's auc: 0.997067
# [1650]	valid_0's binary_logloss: 0.0250818	valid_0's auc: 0.997092
# [1700]	valid_0's binary_logloss: 0.024934	valid_0's auc: 0.997122
# [1750]	valid_0's binary_logloss: 0.0248076	valid_0's auc: 0.99715
# [1800]	valid_0's binary_logloss: 0.0246694	valid_0's auc: 0.997187
# [1850]	valid_0's binary_logloss: 0.0245548	valid_0's auc: 0.997211
# [1900]	valid_0's binary_logloss: 0.0244369	valid_0's auc: 0.997237
# [1950]	valid_0's binary_logloss: 0.0243142	valid_0's auc: 0.997267
# [2000]	valid_0's binary_logloss: 0.0241883	valid_0's auc: 0.997297
# [2050]	valid_0's binary_logloss: 0.0240798	valid_0's auc: 0.997321
# [2100]	valid_0's binary_logloss: 0.02397	valid_0's auc: 0.997345
# [2150]	valid_0's binary_logloss: 0.0238513	valid_0's auc: 0.997367
# [2200]	valid_0's binary_logloss: 0.0237491	valid_0's auc: 0.99739
# [2250]	valid_0's binary_logloss: 0.0236424	valid_0's auc: 0.99741
# [2300]	valid_0's binary_logloss: 0.0235251	valid_0's auc: 0.997432
# [2350]	valid_0's binary_logloss: 0.0233956	valid_0's auc: 0.997459
# [2400]	valid_0's binary_logloss: 0.0233092	valid_0's auc: 0.997476
# [2450]	valid_0's binary_logloss: 0.0231958	valid_0's auc: 0.997498
# [2500]	valid_0's binary_logloss: 0.0230934	valid_0's auc: 0.997519
# [2550]	valid_0's binary_logloss: 0.0229818	valid_0's auc: 0.997546
# [2600]	valid_0's binary_logloss: 0.0228686	valid_0's auc: 0.997571
# [2650]	valid_0's binary_logloss: 0.0227724	valid_0's auc: 0.997591
# [2700]	valid_0's binary_logloss: 0.0226666	valid_0's auc: 0.997611
# [2750]	valid_0's binary_logloss: 0.0225742	valid_0's auc: 0.997627
# [2800]	valid_0's binary_logloss: 0.0224742	valid_0's auc: 0.997649
# [2850]	valid_0's binary_logloss: 0.02238	valid_0's auc: 0.997668
# [2900]	valid_0's binary_logloss: 0.0222842	valid_0's auc: 0.997685
# [2950]	valid_0's binary_logloss: 0.0221972	valid_0's auc: 0.997702
# [3000]	valid_0's binary_logloss: 0.0220925	valid_0's auc: 0.997721
#
# == fold 4 ==
# [50]	valid_0's binary_logloss: 0.0345034	valid_0's auc: 0.99431
# [100]	valid_0's binary_logloss: 0.0327814	valid_0's auc: 0.99491
# [150]	valid_0's binary_logloss: 0.0319405	valid_0's auc: 0.995192
# [200]	valid_0's binary_logloss: 0.031325	valid_0's auc: 0.995385
# [250]	valid_0's binary_logloss: 0.0308155	valid_0's auc: 0.995574
# [300]	valid_0's binary_logloss: 0.0303773	valid_0's auc: 0.995726
# [350]	valid_0's binary_logloss: 0.0299961	valid_0's auc: 0.995846
# [400]	valid_0's binary_logloss: 0.0296764	valid_0's auc: 0.995946
# [450]	valid_0's binary_logloss: 0.0293383	valid_0's auc: 0.996035
# [500]	valid_0's binary_logloss: 0.0290823	valid_0's auc: 0.996102
# [550]	valid_0's binary_logloss: 0.0288093	valid_0's auc: 0.996181
# [600]	valid_0's binary_logloss: 0.0285976	valid_0's auc: 0.996252
# [650]	valid_0's binary_logloss: 0.0283718	valid_0's auc: 0.996306
# [700]	valid_0's binary_logloss: 0.0281387	valid_0's auc: 0.996375
# [750]	valid_0's binary_logloss: 0.0279536	valid_0's auc: 0.996428
# [800]	valid_0's binary_logloss: 0.0277218	valid_0's auc: 0.996492
# [850]	valid_0's binary_logloss: 0.0275054	valid_0's auc: 0.996551
# [900]	valid_0's binary_logloss: 0.0273212	valid_0's auc: 0.996604
# [950]	valid_0's binary_logloss: 0.0271026	valid_0's auc: 0.99666
# [1000]	valid_0's binary_logloss: 0.0269173	valid_0's auc: 0.996702
# [1050]	valid_0's binary_logloss: 0.0267439	valid_0's auc: 0.996748
# [1100]	valid_0's binary_logloss: 0.0265574	valid_0's auc: 0.996798
# [1150]	valid_0's binary_logloss: 0.0263847	valid_0's auc: 0.996834
# [1200]	valid_0's binary_logloss: 0.0261987	valid_0's auc: 0.996876
# [1250]	valid_0's binary_logloss: 0.0260124	valid_0's auc: 0.996925
# [1300]	valid_0's binary_logloss: 0.0258521	valid_0's auc: 0.996963
# [1350]	valid_0's binary_logloss: 0.0257008	valid_0's auc: 0.997005
# [1400]	valid_0's binary_logloss: 0.0255365	valid_0's auc: 0.99704
# [1450]	valid_0's binary_logloss: 0.0253526	valid_0's auc: 0.997086
# [1500]	valid_0's binary_logloss: 0.0251994	valid_0's auc: 0.997124
# [1550]	valid_0's binary_logloss: 0.0250457	valid_0's auc: 0.997158
# [1600]	valid_0's binary_logloss: 0.0249005	valid_0's auc: 0.997188
# [1650]	valid_0's binary_logloss: 0.0247518	valid_0's auc: 0.997216
# [1700]	valid_0's binary_logloss: 0.0246257	valid_0's auc: 0.997243
# [1750]	valid_0's binary_logloss: 0.0245093	valid_0's auc: 0.997267
# [1800]	valid_0's binary_logloss: 0.0243774	valid_0's auc: 0.997293
# [1850]	valid_0's binary_logloss: 0.0242638	valid_0's auc: 0.997317
# [1900]	valid_0's binary_logloss: 0.0241248	valid_0's auc: 0.997351
# [1950]	valid_0's binary_logloss: 0.0239989	valid_0's auc: 0.997375
# [2000]	valid_0's binary_logloss: 0.0238875	valid_0's auc: 0.997398
# [2050]	valid_0's binary_logloss: 0.0237696	valid_0's auc: 0.997418
# [2100]	valid_0's binary_logloss: 0.0236547	valid_0's auc: 0.99744
# [2150]	valid_0's binary_logloss: 0.023519	valid_0's auc: 0.997466
# [2200]	valid_0's binary_logloss: 0.0233972	valid_0's auc: 0.997493
# [2250]	valid_0's binary_logloss: 0.0233051	valid_0's auc: 0.997508
# [2300]	valid_0's binary_logloss: 0.0232022	valid_0's auc: 0.997527
# [2350]	valid_0's binary_logloss: 0.0230937	valid_0's auc: 0.997546
# [2400]	valid_0's binary_logloss: 0.0229811	valid_0's auc: 0.997567
# [2450]	valid_0's binary_logloss: 0.0228839	valid_0's auc: 0.997583
# [2500]	valid_0's binary_logloss: 0.0227898	valid_0's auc: 0.997597
# [2550]	valid_0's binary_logloss: 0.0226821	valid_0's auc: 0.997616
# [2600]	valid_0's binary_logloss: 0.0225873	valid_0's auc: 0.997632
# [2650]	valid_0's binary_logloss: 0.0224898	valid_0's auc: 0.99765
# [2700]	valid_0's binary_logloss: 0.0223948	valid_0's auc: 0.997667
# [2750]	valid_0's binary_logloss: 0.0223047	valid_0's auc: 0.997681
# [2800]	valid_0's binary_logloss: 0.0222042	valid_0's auc: 0.997699
# [2850]	valid_0's binary_logloss: 0.0221241	valid_0's auc: 0.997713
# [2900]	valid_0's binary_logloss: 0.0220289	valid_0's auc: 0.997729
# [2950]	valid_0's binary_logloss: 0.0219362	valid_0's auc: 0.997746
# [3000]	valid_0's binary_logloss: 0.0218657	valid_0's auc: 0.997759
#
# == fold 5 ==
# [50]	valid_0's binary_logloss: 0.0345646	valid_0's auc: 0.994201
# [100]	valid_0's binary_logloss: 0.0328996	valid_0's auc: 0.994783
# [150]	valid_0's binary_logloss: 0.0320254	valid_0's auc: 0.995102
# [200]	valid_0's binary_logloss: 0.0313979	valid_0's auc: 0.995337
# [250]	valid_0's binary_logloss: 0.0309016	valid_0's auc: 0.995508
# [300]	valid_0's binary_logloss: 0.0304565	valid_0's auc: 0.995643
# [350]	valid_0's binary_logloss: 0.0301142	valid_0's auc: 0.995752
# [400]	valid_0's binary_logloss: 0.0297784	valid_0's auc: 0.995861
# [450]	valid_0's binary_logloss: 0.0294862	valid_0's auc: 0.995954
# [500]	valid_0's binary_logloss: 0.0291743	valid_0's auc: 0.996045
# [550]	valid_0's binary_logloss: 0.0289333	valid_0's auc: 0.996118
# [600]	valid_0's binary_logloss: 0.0286705	valid_0's auc: 0.9962
# [650]	valid_0's binary_logloss: 0.0284266	valid_0's auc: 0.996263
# [700]	valid_0's binary_logloss: 0.028179	valid_0's auc: 0.996327
# [750]	valid_0's binary_logloss: 0.0279699	valid_0's auc: 0.996396
# [800]	valid_0's binary_logloss: 0.0277218	valid_0's auc: 0.996476
# [850]	valid_0's binary_logloss: 0.027517	valid_0's auc: 0.996532
# [900]	valid_0's binary_logloss: 0.0273383	valid_0's auc: 0.996586
# [950]	valid_0's binary_logloss: 0.0271223	valid_0's auc: 0.996638
# [1000]	valid_0's binary_logloss: 0.0269484	valid_0's auc: 0.996685
# [1050]	valid_0's binary_logloss: 0.026761	valid_0's auc: 0.996736
# [1100]	valid_0's binary_logloss: 0.0265928	valid_0's auc: 0.99678
# [1150]	valid_0's binary_logloss: 0.0264392	valid_0's auc: 0.996813
# [1200]	valid_0's binary_logloss: 0.0262726	valid_0's auc: 0.996854
# [1250]	valid_0's binary_logloss: 0.0261175	valid_0's auc: 0.996899
# [1300]	valid_0's binary_logloss: 0.0259749	valid_0's auc: 0.996932
# [1350]	valid_0's binary_logloss: 0.0258212	valid_0's auc: 0.996966
# [1400]	valid_0's binary_logloss: 0.025677	valid_0's auc: 0.996999
# [1450]	valid_0's binary_logloss: 0.0255208	valid_0's auc: 0.99704
# [1500]	valid_0's binary_logloss: 0.0253586	valid_0's auc: 0.997075
# [1550]	valid_0's binary_logloss: 0.0252292	valid_0's auc: 0.997106
# [1600]	valid_0's binary_logloss: 0.0250759	valid_0's auc: 0.997143
# [1650]	valid_0's binary_logloss: 0.0249428	valid_0's auc: 0.997178
# [1700]	valid_0's binary_logloss: 0.0248181	valid_0's auc: 0.997199
# [1750]	valid_0's binary_logloss: 0.0246803	valid_0's auc: 0.997229
# [1800]	valid_0's binary_logloss: 0.0245471	valid_0's auc: 0.997256
# [1850]	valid_0's binary_logloss: 0.0244117	valid_0's auc: 0.997284
# [1900]	valid_0's binary_logloss: 0.0242874	valid_0's auc: 0.997313
# [1950]	valid_0's binary_logloss: 0.0241719	valid_0's auc: 0.997336
# [2000]	valid_0's binary_logloss: 0.0240353	valid_0's auc: 0.997366
# [2050]	valid_0's binary_logloss: 0.0238995	valid_0's auc: 0.997394
# [2100]	valid_0's binary_logloss: 0.0237821	valid_0's auc: 0.997418
# [2150]	valid_0's binary_logloss: 0.0236601	valid_0's auc: 0.997443
# [2200]	valid_0's binary_logloss: 0.0235439	valid_0's auc: 0.997464
# [2250]	valid_0's binary_logloss: 0.0234482	valid_0's auc: 0.997484
# [2300]	valid_0's binary_logloss: 0.0233332	valid_0's auc: 0.997505
# [2350]	valid_0's binary_logloss: 0.0232095	valid_0's auc: 0.997528
# [2400]	valid_0's binary_logloss: 0.0230778	valid_0's auc: 0.997558
# [2450]	valid_0's binary_logloss: 0.0229673	valid_0's auc: 0.997581
# [2500]	valid_0's binary_logloss: 0.0228791	valid_0's auc: 0.997595
# [2550]	valid_0's binary_logloss: 0.0227624	valid_0's auc: 0.997618
# [2600]	valid_0's binary_logloss: 0.0226602	valid_0's auc: 0.997639
# [2650]	valid_0's binary_logloss: 0.0225532	valid_0's auc: 0.99766
# [2700]	valid_0's binary_logloss: 0.022447	valid_0's auc: 0.997682
# [2750]	valid_0's binary_logloss: 0.0223628	valid_0's auc: 0.997697
# [2800]	valid_0's binary_logloss: 0.0222646	valid_0's auc: 0.997718
# [2850]	valid_0's binary_logloss: 0.0221698	valid_0's auc: 0.997734
# [2900]	valid_0's binary_logloss: 0.0220609	valid_0's auc: 0.99775
# [2950]	valid_0's binary_logloss: 0.0219625	valid_0's auc: 0.997769
# [3000]	valid_0's binary_logloss: 0.0218662	valid_0's auc: 0.997787
#
# == fold 6 ==
# [50]	valid_0's binary_logloss: 0.0344658	valid_0's auc: 0.994269
# [100]	valid_0's binary_logloss: 0.0329157	valid_0's auc: 0.994792
# [150]	valid_0's binary_logloss: 0.0320018	valid_0's auc: 0.995118
# [200]	valid_0's binary_logloss: 0.0314528	valid_0's auc: 0.995317
# [250]	valid_0's binary_logloss: 0.0309678	valid_0's auc: 0.995481
# [300]	valid_0's binary_logloss: 0.0305692	valid_0's auc: 0.995611
# [350]	valid_0's binary_logloss: 0.0301349	valid_0's auc: 0.995763
# [400]	valid_0's binary_logloss: 0.0297892	valid_0's auc: 0.995888
# [450]	valid_0's binary_logloss: 0.0295145	valid_0's auc: 0.995977
# [500]	valid_0's binary_logloss: 0.0292307	valid_0's auc: 0.99607
# [550]	valid_0's binary_logloss: 0.0289833	valid_0's auc: 0.996141
# [600]	valid_0's binary_logloss: 0.028713	valid_0's auc: 0.996213
# [650]	valid_0's binary_logloss: 0.0284312	valid_0's auc: 0.99629
# [700]	valid_0's binary_logloss: 0.0282111	valid_0's auc: 0.996348
# [750]	valid_0's binary_logloss: 0.0279882	valid_0's auc: 0.996413
# [800]	valid_0's binary_logloss: 0.027752	valid_0's auc: 0.996488
# [850]	valid_0's binary_logloss: 0.0275565	valid_0's auc: 0.996539
# [900]	valid_0's binary_logloss: 0.0273414	valid_0's auc: 0.996596
# [950]	valid_0's binary_logloss: 0.0271396	valid_0's auc: 0.996651
# [1000]	valid_0's binary_logloss: 0.0269669	valid_0's auc: 0.996698
# [1050]	valid_0's binary_logloss: 0.0267971	valid_0's auc: 0.996741
# [1100]	valid_0's binary_logloss: 0.0266008	valid_0's auc: 0.996789
# [1150]	valid_0's binary_logloss: 0.0264156	valid_0's auc: 0.996841
# [1200]	valid_0's binary_logloss: 0.0262493	valid_0's auc: 0.996879
# [1250]	valid_0's binary_logloss: 0.0260897	valid_0's auc: 0.996908
# [1300]	valid_0's binary_logloss: 0.0259323	valid_0's auc: 0.99695
# [1350]	valid_0's binary_logloss: 0.0257671	valid_0's auc: 0.996994
# [1400]	valid_0's binary_logloss: 0.0256033	valid_0's auc: 0.997032
# [1450]	valid_0's binary_logloss: 0.0254557	valid_0's auc: 0.997067
# [1500]	valid_0's binary_logloss: 0.0253177	valid_0's auc: 0.997101
# [1550]	valid_0's binary_logloss: 0.0251682	valid_0's auc: 0.997136
# [1600]	valid_0's binary_logloss: 0.0250395	valid_0's auc: 0.997166
# [1650]	valid_0's binary_logloss: 0.0249143	valid_0's auc: 0.997197
# [1700]	valid_0's binary_logloss: 0.0248056	valid_0's auc: 0.997222
# [1750]	valid_0's binary_logloss: 0.0246998	valid_0's auc: 0.997244
# [1800]	valid_0's binary_logloss: 0.0245745	valid_0's auc: 0.997275
# [1850]	valid_0's binary_logloss: 0.0244393	valid_0's auc: 0.997301
# [1900]	valid_0's binary_logloss: 0.0242789	valid_0's auc: 0.997339
# [1950]	valid_0's binary_logloss: 0.0241652	valid_0's auc: 0.997362
# [2000]	valid_0's binary_logloss: 0.0240229	valid_0's auc: 0.997393
# [2050]	valid_0's binary_logloss: 0.0238927	valid_0's auc: 0.997419
# [2100]	valid_0's binary_logloss: 0.0237785	valid_0's auc: 0.997441
# [2150]	valid_0's binary_logloss: 0.0236595	valid_0's auc: 0.997465
# [2200]	valid_0's binary_logloss: 0.0235417	valid_0's auc: 0.997489
# [2250]	valid_0's binary_logloss: 0.0234215	valid_0's auc: 0.99751
# [2300]	valid_0's binary_logloss: 0.023292	valid_0's auc: 0.997534
# [2350]	valid_0's binary_logloss: 0.0231789	valid_0's auc: 0.997559
# [2400]	valid_0's binary_logloss: 0.0230512	valid_0's auc: 0.997585
# [2450]	valid_0's binary_logloss: 0.0229547	valid_0's auc: 0.997603
# [2500]	valid_0's binary_logloss: 0.0228523	valid_0's auc: 0.997628
# [2550]	valid_0's binary_logloss: 0.022729	valid_0's auc: 0.997652
# [2600]	valid_0's binary_logloss: 0.0226254	valid_0's auc: 0.997672
# [2650]	valid_0's binary_logloss: 0.0225052	valid_0's auc: 0.997697
# [2700]	valid_0's binary_logloss: 0.0224044	valid_0's auc: 0.997715
# [2750]	valid_0's binary_logloss: 0.0222948	valid_0's auc: 0.997735
# [2800]	valid_0's binary_logloss: 0.0221996	valid_0's auc: 0.997752
# [2850]	valid_0's binary_logloss: 0.0220925	valid_0's auc: 0.99777
# [2900]	valid_0's binary_logloss: 0.0219922	valid_0's auc: 0.997787
# [2950]	valid_0's binary_logloss: 0.0219013	valid_0's auc: 0.997802
# [3000]	valid_0's binary_logloss: 0.0218243	valid_0's auc: 0.997817
#
# CV-accuracy: 0.992404964281988

# %%
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# == fold 0 ==
# [50]	valid_0's binary_logloss: 0.0338232	valid_0's auc: 0.994501
# [100]	valid_0's binary_logloss: 0.032296	valid_0's auc: 0.99506
# [150]	valid_0's binary_logloss: 0.0314737	valid_0's auc: 0.99534
# [200]	valid_0's binary_logloss: 0.0307172	valid_0's auc: 0.995599
# [250]	valid_0's binary_logloss: 0.0302381	valid_0's auc: 0.99576
# [300]	valid_0's binary_logloss: 0.0297468	valid_0's auc: 0.995916
# [350]	valid_0's binary_logloss: 0.0294099	valid_0's auc: 0.996016
# [400]	valid_0's binary_logloss: 0.0290811	valid_0's auc: 0.996116
# [450]	valid_0's binary_logloss: 0.0287374	valid_0's auc: 0.996202
# [500]	valid_0's binary_logloss: 0.0283971	valid_0's auc: 0.996306
# [550]	valid_0's binary_logloss: 0.0280459	valid_0's auc: 0.996401
# [600]	valid_0's binary_logloss: 0.0277365	valid_0's auc: 0.996485
# [650]	valid_0's binary_logloss: 0.027426	valid_0's auc: 0.996567
# [700]	valid_0's binary_logloss: 0.0271547	valid_0's auc: 0.99664
# [750]	valid_0's binary_logloss: 0.0268985	valid_0's auc: 0.996705
# [800]	valid_0's binary_logloss: 0.0266564	valid_0's auc: 0.996761
# [850]	valid_0's binary_logloss: 0.0264288	valid_0's auc: 0.996814
# [900]	valid_0's binary_logloss: 0.0262244	valid_0's auc: 0.996866
# [950]	valid_0's binary_logloss: 0.0260077	valid_0's auc: 0.996916
# [1000]	valid_0's binary_logloss: 0.0257845	valid_0's auc: 0.99697
# [1050]	valid_0's binary_logloss: 0.0255699	valid_0's auc: 0.997013
# [1100]	valid_0's binary_logloss: 0.0253485	valid_0's auc: 0.997055
# [1150]	valid_0's binary_logloss: 0.0251613	valid_0's auc: 0.997098
# [1200]	valid_0's binary_logloss: 0.0249401	valid_0's auc: 0.997151
# [1250]	valid_0's binary_logloss: 0.0247216	valid_0's auc: 0.997196
# [1300]	valid_0's binary_logloss: 0.0245442	valid_0's auc: 0.997231
# [1350]	valid_0's binary_logloss: 0.0243692	valid_0's auc: 0.997268
# [1400]	valid_0's binary_logloss: 0.0241503	valid_0's auc: 0.997312
# [1450]	valid_0's binary_logloss: 0.0239811	valid_0's auc: 0.997349
# [1500]	valid_0's binary_logloss: 0.0238059	valid_0's auc: 0.997386
# [1550]	valid_0's binary_logloss: 0.0236256	valid_0's auc: 0.997419
# [1600]	valid_0's binary_logloss: 0.0234763	valid_0's auc: 0.997447
# [1650]	valid_0's binary_logloss: 0.0233027	valid_0's auc: 0.997477
# [1700]	valid_0's binary_logloss: 0.0231126	valid_0's auc: 0.99751
# [1750]	valid_0's binary_logloss: 0.0229587	valid_0's auc: 0.997543
# [1800]	valid_0's binary_logloss: 0.0227961	valid_0's auc: 0.997571
# [1850]	valid_0's binary_logloss: 0.0226424	valid_0's auc: 0.997598
# [1900]	valid_0's binary_logloss: 0.0225002	valid_0's auc: 0.997623
# [1950]	valid_0's binary_logloss: 0.0223474	valid_0's auc: 0.997651
# [2000]	valid_0's binary_logloss: 0.022215	valid_0's auc: 0.997676
# [2050]	valid_0's binary_logloss: 0.0220471	valid_0's auc: 0.997705
# [2100]	valid_0's binary_logloss: 0.021913	valid_0's auc: 0.997726
# [2150]	valid_0's binary_logloss: 0.0217527	valid_0's auc: 0.997756
# [2200]	valid_0's binary_logloss: 0.0216163	valid_0's auc: 0.997779
# [2250]	valid_0's binary_logloss: 0.0214867	valid_0's auc: 0.997801
# [2300]	valid_0's binary_logloss: 0.0213298	valid_0's auc: 0.997828
# [2350]	valid_0's binary_logloss: 0.0211895	valid_0's auc: 0.997849
# [2400]	valid_0's binary_logloss: 0.0210626	valid_0's auc: 0.997868
# [2450]	valid_0's binary_logloss: 0.020936	valid_0's auc: 0.997889
# [2500]	valid_0's binary_logloss: 0.0208182	valid_0's auc: 0.997906
# [2550]	valid_0's binary_logloss: 0.0207198	valid_0's auc: 0.997919
# [2600]	valid_0's binary_logloss: 0.0206103	valid_0's auc: 0.997934
# [2650]	valid_0's binary_logloss: 0.0204967	valid_0's auc: 0.997951
# [2700]	valid_0's binary_logloss: 0.0203848	valid_0's auc: 0.997969
# [2750]	valid_0's binary_logloss: 0.020273	valid_0's auc: 0.997985
# [2800]	valid_0's binary_logloss: 0.0201677	valid_0's auc: 0.998
# [2850]	valid_0's binary_logloss: 0.0200721	valid_0's auc: 0.998015
# [2900]	valid_0's binary_logloss: 0.0199868	valid_0's auc: 0.998025
# [2950]	valid_0's binary_logloss: 0.0198758	valid_0's auc: 0.99804
# [3000]	valid_0's binary_logloss: 0.0197742	valid_0's auc: 0.998052
#
# == fold 1 ==
# [50]	valid_0's binary_logloss: 0.0336511	valid_0's auc: 0.994636
# [100]	valid_0's binary_logloss: 0.0321517	valid_0's auc: 0.995182
# [150]	valid_0's binary_logloss: 0.0312623	valid_0's auc: 0.995477
# [200]	valid_0's binary_logloss: 0.0306544	valid_0's auc: 0.995665
# [250]	valid_0's binary_logloss: 0.0301448	valid_0's auc: 0.995824
# [300]	valid_0's binary_logloss: 0.0296839	valid_0's auc: 0.995976
# [350]	valid_0's binary_logloss: 0.0292409	valid_0's auc: 0.996096
# [400]	valid_0's binary_logloss: 0.0288191	valid_0's auc: 0.996218
# [450]	valid_0's binary_logloss: 0.0284612	valid_0's auc: 0.996311
# [500]	valid_0's binary_logloss: 0.0281563	valid_0's auc: 0.996398
# [550]	valid_0's binary_logloss: 0.0278685	valid_0's auc: 0.996471
# [600]	valid_0's binary_logloss: 0.0275809	valid_0's auc: 0.996553
# [650]	valid_0's binary_logloss: 0.0272785	valid_0's auc: 0.996637
# [700]	valid_0's binary_logloss: 0.0270139	valid_0's auc: 0.996699
# [750]	valid_0's binary_logloss: 0.0267226	valid_0's auc: 0.996761
# [800]	valid_0's binary_logloss: 0.0264644	valid_0's auc: 0.996826
# [850]	valid_0's binary_logloss: 0.0261912	valid_0's auc: 0.996897
# [900]	valid_0's binary_logloss: 0.0259416	valid_0's auc: 0.996958
# [950]	valid_0's binary_logloss: 0.0257401	valid_0's auc: 0.997004
# [1000]	valid_0's binary_logloss: 0.0255131	valid_0's auc: 0.997062
# [1050]	valid_0's binary_logloss: 0.0252912	valid_0's auc: 0.997109
# [1100]	valid_0's binary_logloss: 0.0250995	valid_0's auc: 0.997151
# [1150]	valid_0's binary_logloss: 0.0248761	valid_0's auc: 0.997202
# [1200]	valid_0's binary_logloss: 0.0246772	valid_0's auc: 0.997245
# [1250]	valid_0's binary_logloss: 0.0244535	valid_0's auc: 0.997296
# [1300]	valid_0's binary_logloss: 0.0242925	valid_0's auc: 0.99733
# [1350]	valid_0's binary_logloss: 0.0240921	valid_0's auc: 0.997377
# [1400]	valid_0's binary_logloss: 0.0239105	valid_0's auc: 0.997416
# [1450]	valid_0's binary_logloss: 0.0237646	valid_0's auc: 0.997445
# [1500]	valid_0's binary_logloss: 0.0236033	valid_0's auc: 0.997475
# [1550]	valid_0's binary_logloss: 0.0234549	valid_0's auc: 0.997505
# [1600]	valid_0's binary_logloss: 0.0232683	valid_0's auc: 0.997545
# [1650]	valid_0's binary_logloss: 0.0230966	valid_0's auc: 0.997578
# [1700]	valid_0's binary_logloss: 0.0229184	valid_0's auc: 0.99761
# [1750]	valid_0's binary_logloss: 0.0227481	valid_0's auc: 0.997641
# [1800]	valid_0's binary_logloss: 0.0225807	valid_0's auc: 0.99767
# [1850]	valid_0's binary_logloss: 0.0224403	valid_0's auc: 0.997699
# [1900]	valid_0's binary_logloss: 0.0222924	valid_0's auc: 0.997728
# [1950]	valid_0's binary_logloss: 0.0221367	valid_0's auc: 0.997762
# [2000]	valid_0's binary_logloss: 0.0219827	valid_0's auc: 0.997787
# [2050]	valid_0's binary_logloss: 0.0218256	valid_0's auc: 0.997815
# [2100]	valid_0's binary_logloss: 0.0216909	valid_0's auc: 0.997838
# [2150]	valid_0's binary_logloss: 0.0215498	valid_0's auc: 0.997858
# [2200]	valid_0's binary_logloss: 0.0214058	valid_0's auc: 0.997879
# [2250]	valid_0's binary_logloss: 0.0212798	valid_0's auc: 0.997898
# [2300]	valid_0's binary_logloss: 0.0211336	valid_0's auc: 0.997921
# [2350]	valid_0's binary_logloss: 0.0210155	valid_0's auc: 0.997936
# [2400]	valid_0's binary_logloss: 0.0208991	valid_0's auc: 0.997954
# [2450]	valid_0's binary_logloss: 0.0207931	valid_0's auc: 0.99797
# [2500]	valid_0's binary_logloss: 0.0206733	valid_0's auc: 0.997988
# [2550]	valid_0's binary_logloss: 0.0205464	valid_0's auc: 0.998007
# [2600]	valid_0's binary_logloss: 0.0204164	valid_0's auc: 0.998029
# [2650]	valid_0's binary_logloss: 0.0203034	valid_0's auc: 0.998046
# [2700]	valid_0's binary_logloss: 0.0201825	valid_0's auc: 0.998064
# [2750]	valid_0's binary_logloss: 0.0200765	valid_0's auc: 0.998078
# [2800]	valid_0's binary_logloss: 0.0199596	valid_0's auc: 0.998093
# [2850]	valid_0's binary_logloss: 0.0198599	valid_0's auc: 0.998107
# [2900]	valid_0's binary_logloss: 0.0197341	valid_0's auc: 0.998124
# [2950]	valid_0's binary_logloss: 0.0196285	valid_0's auc: 0.998139
# [3000]	valid_0's binary_logloss: 0.0195323	valid_0's auc: 0.998153
#
# == fold 2 ==
# [50]	valid_0's binary_logloss: 0.0338264	valid_0's auc: 0.994535
# [100]	valid_0's binary_logloss: 0.0322386	valid_0's auc: 0.995122
# [150]	valid_0's binary_logloss: 0.0314059	valid_0's auc: 0.99542
# [200]	valid_0's binary_logloss: 0.0307066	valid_0's auc: 0.995646
# [250]	valid_0's binary_logloss: 0.0301742	valid_0's auc: 0.995819
# [300]	valid_0's binary_logloss: 0.0297144	valid_0's auc: 0.995964
# [350]	valid_0's binary_logloss: 0.0293438	valid_0's auc: 0.996066
# [400]	valid_0's binary_logloss: 0.028996	valid_0's auc: 0.996162
# [450]	valid_0's binary_logloss: 0.0286391	valid_0's auc: 0.996258
# [500]	valid_0's binary_logloss: 0.0283398	valid_0's auc: 0.996348
# [550]	valid_0's binary_logloss: 0.0280055	valid_0's auc: 0.996453
# [600]	valid_0's binary_logloss: 0.027713	valid_0's auc: 0.996528
# [650]	valid_0's binary_logloss: 0.0274316	valid_0's auc: 0.996599
# [700]	valid_0's binary_logloss: 0.027154	valid_0's auc: 0.996671
# [750]	valid_0's binary_logloss: 0.0268738	valid_0's auc: 0.996732
# [800]	valid_0's binary_logloss: 0.0266522	valid_0's auc: 0.996786
# [850]	valid_0's binary_logloss: 0.0264096	valid_0's auc: 0.996848
# [900]	valid_0's binary_logloss: 0.0261901	valid_0's auc: 0.996902
# [950]	valid_0's binary_logloss: 0.0259261	valid_0's auc: 0.996965
# [1000]	valid_0's binary_logloss: 0.0256779	valid_0's auc: 0.99702
# [1050]	valid_0's binary_logloss: 0.0254413	valid_0's auc: 0.99707
# [1100]	valid_0's binary_logloss: 0.0252356	valid_0's auc: 0.997117
# [1150]	valid_0's binary_logloss: 0.0250216	valid_0's auc: 0.997157
# [1200]	valid_0's binary_logloss: 0.0248498	valid_0's auc: 0.997196
# [1250]	valid_0's binary_logloss: 0.0246561	valid_0's auc: 0.997247
# [1300]	valid_0's binary_logloss: 0.0244598	valid_0's auc: 0.997284
# [1350]	valid_0's binary_logloss: 0.0242613	valid_0's auc: 0.997325
# [1400]	valid_0's binary_logloss: 0.0240833	valid_0's auc: 0.997365
# [1450]	valid_0's binary_logloss: 0.0239057	valid_0's auc: 0.997402
# [1500]	valid_0's binary_logloss: 0.023744	valid_0's auc: 0.997437
# [1550]	valid_0's binary_logloss: 0.0235665	valid_0's auc: 0.997473
# [1600]	valid_0's binary_logloss: 0.0233882	valid_0's auc: 0.997507
# [1650]	valid_0's binary_logloss: 0.0232264	valid_0's auc: 0.997543
# [1700]	valid_0's binary_logloss: 0.0230339	valid_0's auc: 0.997578
# [1750]	valid_0's binary_logloss: 0.0228714	valid_0's auc: 0.997608
# [1800]	valid_0's binary_logloss: 0.0226877	valid_0's auc: 0.997643
# [1850]	valid_0's binary_logloss: 0.0225256	valid_0's auc: 0.997671
# [1900]	valid_0's binary_logloss: 0.0223628	valid_0's auc: 0.997697
# [1950]	valid_0's binary_logloss: 0.0222025	valid_0's auc: 0.997723
# [2000]	valid_0's binary_logloss: 0.0220587	valid_0's auc: 0.997747
# [2050]	valid_0's binary_logloss: 0.0219219	valid_0's auc: 0.99777
# [2100]	valid_0's binary_logloss: 0.0217987	valid_0's auc: 0.997791
# [2150]	valid_0's binary_logloss: 0.0216634	valid_0's auc: 0.997811
# [2200]	valid_0's binary_logloss: 0.0215011	valid_0's auc: 0.997842
# [2250]	valid_0's binary_logloss: 0.0213794	valid_0's auc: 0.997866
# [2300]	valid_0's binary_logloss: 0.0212522	valid_0's auc: 0.997885
# [2350]	valid_0's binary_logloss: 0.0211262	valid_0's auc: 0.997907
# [2400]	valid_0's binary_logloss: 0.020992	valid_0's auc: 0.997925
# [2450]	valid_0's binary_logloss: 0.0208644	valid_0's auc: 0.997943
# [2500]	valid_0's binary_logloss: 0.0207494	valid_0's auc: 0.99796
# [2550]	valid_0's binary_logloss: 0.0206209	valid_0's auc: 0.997978
# [2600]	valid_0's binary_logloss: 0.0205104	valid_0's auc: 0.997994
# [2650]	valid_0's binary_logloss: 0.0204016	valid_0's auc: 0.99801
# [2700]	valid_0's binary_logloss: 0.020294	valid_0's auc: 0.99803
# [2750]	valid_0's binary_logloss: 0.0201735	valid_0's auc: 0.998046
# [2800]	valid_0's binary_logloss: 0.0200698	valid_0's auc: 0.998061
# [2850]	valid_0's binary_logloss: 0.0199677	valid_0's auc: 0.998076
# [2900]	valid_0's binary_logloss: 0.0198678	valid_0's auc: 0.99809
# [2950]	valid_0's binary_logloss: 0.0197657	valid_0's auc: 0.998104
# [3000]	valid_0's binary_logloss: 0.0196452	valid_0's auc: 0.998122
#
# == fold 3 ==
# [50]	valid_0's binary_logloss: 0.0337277	valid_0's auc: 0.994609
# [100]	valid_0's binary_logloss: 0.0320632	valid_0's auc: 0.995194
# [150]	valid_0's binary_logloss: 0.0312042	valid_0's auc: 0.995468
# [200]	valid_0's binary_logloss: 0.0306066	valid_0's auc: 0.995645
# [250]	valid_0's binary_logloss: 0.0301307	valid_0's auc: 0.995792
# [300]	valid_0's binary_logloss: 0.0296889	valid_0's auc: 0.995931
# [350]	valid_0's binary_logloss: 0.0292974	valid_0's auc: 0.996046
# [400]	valid_0's binary_logloss: 0.0289286	valid_0's auc: 0.996154
# [450]	valid_0's binary_logloss: 0.0285739	valid_0's auc: 0.996253
# [500]	valid_0's binary_logloss: 0.0282491	valid_0's auc: 0.996346
# [550]	valid_0's binary_logloss: 0.0279325	valid_0's auc: 0.996438
# [600]	valid_0's binary_logloss: 0.0276131	valid_0's auc: 0.996532
# [650]	valid_0's binary_logloss: 0.0273351	valid_0's auc: 0.996599
# [700]	valid_0's binary_logloss: 0.0270659	valid_0's auc: 0.99667
# [750]	valid_0's binary_logloss: 0.0268409	valid_0's auc: 0.996721
# [800]	valid_0's binary_logloss: 0.026591	valid_0's auc: 0.996782
# [850]	valid_0's binary_logloss: 0.0263174	valid_0's auc: 0.996856
# [900]	valid_0's binary_logloss: 0.0260655	valid_0's auc: 0.996918
# [950]	valid_0's binary_logloss: 0.0258469	valid_0's auc: 0.996971
# [1000]	valid_0's binary_logloss: 0.0256318	valid_0's auc: 0.997019
# [1050]	valid_0's binary_logloss: 0.0254486	valid_0's auc: 0.997055
# [1100]	valid_0's binary_logloss: 0.0252431	valid_0's auc: 0.997106
# [1150]	valid_0's binary_logloss: 0.0250151	valid_0's auc: 0.997154
# [1200]	valid_0's binary_logloss: 0.0248173	valid_0's auc: 0.997196
# [1250]	valid_0's binary_logloss: 0.024619	valid_0's auc: 0.997236
# [1300]	valid_0's binary_logloss: 0.0244299	valid_0's auc: 0.997272
# [1350]	valid_0's binary_logloss: 0.0242358	valid_0's auc: 0.997308
# [1400]	valid_0's binary_logloss: 0.0240461	valid_0's auc: 0.997345
# [1450]	valid_0's binary_logloss: 0.0238783	valid_0's auc: 0.997378
# [1500]	valid_0's binary_logloss: 0.0236977	valid_0's auc: 0.997412
# [1550]	valid_0's binary_logloss: 0.0235502	valid_0's auc: 0.997438
# [1600]	valid_0's binary_logloss: 0.0234057	valid_0's auc: 0.997464
# [1650]	valid_0's binary_logloss: 0.0232427	valid_0's auc: 0.997491
# [1700]	valid_0's binary_logloss: 0.0230822	valid_0's auc: 0.997521
# [1750]	valid_0's binary_logloss: 0.0229028	valid_0's auc: 0.997556
# [1800]	valid_0's binary_logloss: 0.0227505	valid_0's auc: 0.997585
# [1850]	valid_0's binary_logloss: 0.0225783	valid_0's auc: 0.997618
# [1900]	valid_0's binary_logloss: 0.0224172	valid_0's auc: 0.99765
# [1950]	valid_0's binary_logloss: 0.0222616	valid_0's auc: 0.997675
# [2000]	valid_0's binary_logloss: 0.0221147	valid_0's auc: 0.997702
# [2050]	valid_0's binary_logloss: 0.0219673	valid_0's auc: 0.997726
# [2100]	valid_0's binary_logloss: 0.0218128	valid_0's auc: 0.997756
# [2150]	valid_0's binary_logloss: 0.0216566	valid_0's auc: 0.997785
# [2200]	valid_0's binary_logloss: 0.0215066	valid_0's auc: 0.997812
# [2250]	valid_0's binary_logloss: 0.0213804	valid_0's auc: 0.99783
# [2300]	valid_0's binary_logloss: 0.0212737	valid_0's auc: 0.997846
# [2350]	valid_0's binary_logloss: 0.021143	valid_0's auc: 0.997866
# [2400]	valid_0's binary_logloss: 0.0210377	valid_0's auc: 0.997879
# [2450]	valid_0's binary_logloss: 0.0209239	valid_0's auc: 0.997895
# [2500]	valid_0's binary_logloss: 0.020789	valid_0's auc: 0.997915
# [2550]	valid_0's binary_logloss: 0.0206744	valid_0's auc: 0.997936
# [2600]	valid_0's binary_logloss: 0.0205779	valid_0's auc: 0.99795
# [2650]	valid_0's binary_logloss: 0.0204501	valid_0's auc: 0.997966
# [2700]	valid_0's binary_logloss: 0.0203535	valid_0's auc: 0.99798
# [2750]	valid_0's binary_logloss: 0.0202375	valid_0's auc: 0.997998
# [2800]	valid_0's binary_logloss: 0.0201231	valid_0's auc: 0.998016
# [2850]	valid_0's binary_logloss: 0.020027	valid_0's auc: 0.998029
# [2900]	valid_0's binary_logloss: 0.0199172	valid_0's auc: 0.998044
# [2950]	valid_0's binary_logloss: 0.019811	valid_0's auc: 0.998059
# [3000]	valid_0's binary_logloss: 0.0196966	valid_0's auc: 0.998077
#
# == fold 4 ==
# [50]	valid_0's binary_logloss: 0.0338736	valid_0's auc: 0.994505
# [100]	valid_0's binary_logloss: 0.0322907	valid_0's auc: 0.995052
# [150]	valid_0's binary_logloss: 0.031496	valid_0's auc: 0.99535
# [200]	valid_0's binary_logloss: 0.0308928	valid_0's auc: 0.995548
# [250]	valid_0's binary_logloss: 0.0303731	valid_0's auc: 0.99572
# [300]	valid_0's binary_logloss: 0.0298753	valid_0's auc: 0.995879
# [350]	valid_0's binary_logloss: 0.0295153	valid_0's auc: 0.995996
# [400]	valid_0's binary_logloss: 0.0291102	valid_0's auc: 0.996117
# [450]	valid_0's binary_logloss: 0.0287751	valid_0's auc: 0.996221
# [500]	valid_0's binary_logloss: 0.0284927	valid_0's auc: 0.996298
# [550]	valid_0's binary_logloss: 0.0281758	valid_0's auc: 0.996385
# [600]	valid_0's binary_logloss: 0.0279137	valid_0's auc: 0.996457
# [650]	valid_0's binary_logloss: 0.0276342	valid_0's auc: 0.99653
# [700]	valid_0's binary_logloss: 0.0273549	valid_0's auc: 0.996607
# [750]	valid_0's binary_logloss: 0.0270546	valid_0's auc: 0.996692
# [800]	valid_0's binary_logloss: 0.0267643	valid_0's auc: 0.996769
# [850]	valid_0's binary_logloss: 0.0265009	valid_0's auc: 0.996834
# [900]	valid_0's binary_logloss: 0.0262491	valid_0's auc: 0.996897
# [950]	valid_0's binary_logloss: 0.0260116	valid_0's auc: 0.996957
# [1000]	valid_0's binary_logloss: 0.0257892	valid_0's auc: 0.997006
# [1050]	valid_0's binary_logloss: 0.0255561	valid_0's auc: 0.997058
# [1100]	valid_0's binary_logloss: 0.0253457	valid_0's auc: 0.997099
# [1150]	valid_0's binary_logloss: 0.025145	valid_0's auc: 0.997143
# [1200]	valid_0's binary_logloss: 0.0249394	valid_0's auc: 0.9972
# [1250]	valid_0's binary_logloss: 0.02471	valid_0's auc: 0.997257
# [1300]	valid_0's binary_logloss: 0.024549	valid_0's auc: 0.997295
# [1350]	valid_0's binary_logloss: 0.0243537	valid_0's auc: 0.997332
# [1400]	valid_0's binary_logloss: 0.0241595	valid_0's auc: 0.997369
# [1450]	valid_0's binary_logloss: 0.0239764	valid_0's auc: 0.997403
# [1500]	valid_0's binary_logloss: 0.0237868	valid_0's auc: 0.997446
# [1550]	valid_0's binary_logloss: 0.0235973	valid_0's auc: 0.997484
# [1600]	valid_0's binary_logloss: 0.0234108	valid_0's auc: 0.997523
# [1650]	valid_0's binary_logloss: 0.0232313	valid_0's auc: 0.997553
# [1700]	valid_0's binary_logloss: 0.0230751	valid_0's auc: 0.997583
# [1750]	valid_0's binary_logloss: 0.0229111	valid_0's auc: 0.997615
# [1800]	valid_0's binary_logloss: 0.0227527	valid_0's auc: 0.997648
# [1850]	valid_0's binary_logloss: 0.0226151	valid_0's auc: 0.997674
# [1900]	valid_0's binary_logloss: 0.0224767	valid_0's auc: 0.997697
# [1950]	valid_0's binary_logloss: 0.0223428	valid_0's auc: 0.997724
# [2000]	valid_0's binary_logloss: 0.0222041	valid_0's auc: 0.99775
# [2050]	valid_0's binary_logloss: 0.0220572	valid_0's auc: 0.997777
# [2100]	valid_0's binary_logloss: 0.0219202	valid_0's auc: 0.997802
# [2150]	valid_0's binary_logloss: 0.0217915	valid_0's auc: 0.997822
# [2200]	valid_0's binary_logloss: 0.021665	valid_0's auc: 0.997844
# [2250]	valid_0's binary_logloss: 0.0215451	valid_0's auc: 0.997865
# [2300]	valid_0's binary_logloss: 0.0214042	valid_0's auc: 0.997887
# [2350]	valid_0's binary_logloss: 0.0212718	valid_0's auc: 0.997911
# [2400]	valid_0's binary_logloss: 0.0211219	valid_0's auc: 0.997935
# [2450]	valid_0's binary_logloss: 0.0209987	valid_0's auc: 0.997951
# [2500]	valid_0's binary_logloss: 0.0208607	valid_0's auc: 0.997974
# [2550]	valid_0's binary_logloss: 0.0207323	valid_0's auc: 0.997993
# [2600]	valid_0's binary_logloss: 0.0206151	valid_0's auc: 0.998008
# [2650]	valid_0's binary_logloss: 0.020535	valid_0's auc: 0.998021
# [2700]	valid_0's binary_logloss: 0.0203897	valid_0's auc: 0.998049
# [2750]	valid_0's binary_logloss: 0.0202782	valid_0's auc: 0.998065
# [2800]	valid_0's binary_logloss: 0.0201551	valid_0's auc: 0.998084
# [2850]	valid_0's binary_logloss: 0.0200403	valid_0's auc: 0.9981
# [2900]	valid_0's binary_logloss: 0.0199453	valid_0's auc: 0.998112
# [2950]	valid_0's binary_logloss: 0.0198438	valid_0's auc: 0.998124
# [3000]	valid_0's binary_logloss: 0.0197256	valid_0's auc: 0.998142
#
# CV-accuracy: 0.9933457120187196

# %%
def plot_importances(models):
    importance_df = pd.DataFrame(models[0].feature_importances_, 
                                 index=TRAIN_FEATURES, 
                                 columns=['importance'])\
                        .sort_values("importance", ascending=False)

    plt.subplots(figsize=(len(TRAIN_FEATURES) // 4, 5))
    plt.bar(importance_df.index, importance_df.importance)
    plt.grid()
    plt.xticks(rotation=90)
    plt.ylabel("importance")
    plt.tight_layout()
    plt.show()

plot_importances(models)

# %%
# !kaggle datasets init -p ../src/models/BinaryModels

# %%
# !kaggle datasets create -p ../src/models/BinaryModels --dir-mode zip

# %%
# !kaggle datasets version -m "Fuzz&Fold" -p ../src/models/BinaryModels --dir-mode zip
# Out:
# Starting upload for file lgb_2set_5f_binary0.pkl
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.6)
# 100%|######################################| 39.7M/39.7M [00:03<00:00, 13.4MB/s]
# Upload successful: lgb_2set_5f_binary0.pkl (40MB)
# Starting upload for file fuzz_from_8724.pkl
# 100%|######################################| 39.5M/39.5M [00:02<00:00, 15.1MB/s]
# Upload successful: fuzz_from_8724.pkl (39MB)
# Starting upload for file fuzz_from_8726.pkl
# 100%|######################################| 39.5M/39.5M [00:06<00:00, 6.47MB/s]
# Upload successful: fuzz_from_8726.pkl (39MB)
# Starting upload for file lgb_fuzz_t25_2set_5f_binary3.pkl
# 100%|######################################| 39.7M/39.7M [00:02<00:00, 16.1MB/s]
# Upload successful: lgb_fuzz_t25_2set_5f_binary3.pkl (40MB)
# Starting upload for file lgb_t25_2set_5f_binary0.pkl
# 100%|######################################| 39.7M/39.7M [00:02<00:00, 15.8MB/s]
# Upload successful: lgb_t25_2set_5f_binary0.pkl (40MB)
# Starting upload for file lgb_fuzz_t25_2set_5f_binary4.pkl
# 100%|######################################| 39.7M/39.7M [00:02<00:00, 15.8MB/s]
# Upload successful: lgb_fuzz_t25_2set_5f_binary4.pkl (40MB)
# Starting upload for file lgb_5f_binary4.pkl
# 100%|######################################| 11.4M/11.4M [00:01<00:00, 6.82MB/s]
# Upload successful: lgb_5f_binary4.pkl (11MB)
# Starting upload for file lgb_2set_5f_binary3.pkl
# 100%|######################################| 39.6M/39.6M [00:03<00:00, 12.0MB/s]
# Upload successful: lgb_2set_5f_binary3.pkl (40MB)
# Starting upload for file lgb_fuzz_t25_2set_5f_binary1.pkl
# 100%|######################################| 39.7M/39.7M [00:02<00:00, 14.7MB/s]
# Upload successful: lgb_fuzz_t25_2set_5f_binary1.pkl (40MB)
# Starting upload for file fuzz_from_8725.pkl
# 100%|######################################| 39.5M/39.5M [00:02<00:00, 15.2MB/s]
# Upload successful: fuzz_from_8725.pkl (39MB)
# Starting upload for file lgb_2set_5f_binary1.pkl
# 100%|######################################| 39.6M/39.6M [00:02<00:00, 14.1MB/s]
# Upload successful: lgb_2set_5f_binary1.pkl (40MB)
# Starting upload for file fuzz_from_8721.pkl
# 100%|######################################| 39.4M/39.4M [00:02<00:00, 14.4MB/s]
# Upload successful: fuzz_from_8721.pkl (39MB)
# Starting upload for file lgbm_binary2.pkl
# 100%|######################################| 11.4M/11.4M [00:01<00:00, 7.81MB/s]
# Upload successful: lgbm_binary2.pkl (11MB)
# Starting upload for file lgb_t25_2set_5f_binary1.pkl
# 100%|######################################| 39.7M/39.7M [00:02<00:00, 15.0MB/s]
# Upload successful: lgb_t25_2set_5f_binary1.pkl (40MB)
# Starting upload for file fuzz_from_8723.pkl
# 100%|######################################| 39.4M/39.4M [00:02<00:00, 14.6MB/s]
# Upload successful: fuzz_from_8723.pkl (39MB)
# Starting upload for file fuzz_from_8722.pkl
# 100%|######################################| 39.5M/39.5M [00:02<00:00, 13.8MB/s]
# Upload successful: fuzz_from_8722.pkl (39MB)
# Starting upload for file .ipynb_checkpoints.zip
# 100%|#########################################| 22.0/22.0 [00:01<00:00, 15.0B/s]
# Upload successful: .ipynb_checkpoints.zip (22B)
# Starting upload for file lgb_2set_5f_binary4.pkl
# 100%|######################################| 39.6M/39.6M [00:02<00:00, 16.9MB/s]
# Upload successful: lgb_2set_5f_binary4.pkl (40MB)
# Starting upload for file lgb_fuzz_t25_2set_5f_binary2.pkl
# 100%|######################################| 39.7M/39.7M [00:02<00:00, 14.0MB/s]
# Upload successful: lgb_fuzz_t25_2set_5f_binary2.pkl (40MB)
# Starting upload for file lgb_fuzz_t25_2set_5f_binary0.pkl
# 100%|######################################| 39.7M/39.7M [00:02<00:00, 14.9MB/s]
# Upload successful: lgb_fuzz_t25_2set_5f_binary0.pkl (40MB)
# Starting upload for file fuzz_from_8720.pkl
# 100%|######################################| 39.4M/39.4M [00:02<00:00, 15.4MB/s]
# Upload successful: fuzz_from_8720.pkl (39MB)
# Starting upload for file lgb_t25_2set_5f_binary2.pkl
# 100%|######################################| 39.7M/39.7M [00:03<00:00, 11.8MB/s]
# Upload successful: lgb_t25_2set_5f_binary2.pkl (40MB)
# Starting upload for file lgb_5f_binary0.pkl
# 100%|######################################| 11.4M/11.4M [00:01<00:00, 6.30MB/s]
# Upload successful: lgb_5f_binary0.pkl (11MB)
# Starting upload for file lgbm_binary0.pkl
# 100%|######################################| 11.4M/11.4M [00:01<00:00, 6.67MB/s]
# Upload successful: lgbm_binary0.pkl (11MB)
# Starting upload for file lgb_t25_2set_5f_binary3.pkl
# 100%|######################################| 39.7M/39.7M [00:02<00:00, 15.3MB/s]
# Upload successful: lgb_t25_2set_5f_binary3.pkl (40MB)
# Starting upload for file lgb_t25_2set_5f_binary4.pkl
# 100%|######################################| 39.7M/39.7M [00:02<00:00, 15.3MB/s]
# Upload successful: lgb_t25_2set_5f_binary4.pkl (40MB)
# Starting upload for file lgb_2set_5f_binary2.pkl
# 100%|######################################| 39.6M/39.6M [00:04<00:00, 9.25MB/s]
# Upload successful: lgb_2set_5f_binary2.pkl (40MB)
# Starting upload for file lgb_5f_binary3.pkl
# 100%|######################################| 11.4M/11.4M [00:01<00:00, 7.34MB/s]
# Upload successful: lgb_5f_binary3.pkl (11MB)
# Starting upload for file lgb_5f_binary2.pkl
# 100%|######################################| 11.4M/11.4M [00:02<00:00, 5.61MB/s]
# Upload successful: lgb_5f_binary2.pkl (11MB)
# Starting upload for file lgbm_binary1.pkl
# 100%|######################################| 11.4M/11.4M [00:01<00:00, 6.02MB/s]
# Upload successful: lgbm_binary1.pkl (11MB)
# Starting upload for file lgb_5f_binary1.pkl
# 100%|######################################| 11.4M/11.4M [00:01<00:00, 6.79MB/s]
# Upload successful: lgb_5f_binary1.pkl (11MB)
# Dataset version is being created. Please check progress at https://www.kaggle.com/tarique7/foursqbinarylgb
